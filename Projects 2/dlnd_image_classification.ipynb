# %% [markdown]
# # 图像分类
#
# 在此项目中，你将对 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图片进行分类。该数据集包含飞机、猫狗和其他物体。你需要预处理这些图片，然后用所有样本训练一个卷积神经网络。图片需要标准化（normalized），标签需要采用 one-hot 编码。你需要应用所学的知识构建卷积的、最大池化（max pooling）、丢弃（dropout）和完全连接（fully connected）的层。最后，你需要在样本图片上看到神经网络的预测结果。
#
#
# ## 获取数据
#
# 请运行以下单元，以下载 [CIFAR-10 数据集（Python版）](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## 探索数据
#
# 该数据集分成了几部分／批次（batches），以免你的机器在计算时内存不足。CIFAR-10 数据集包含 5 个部分，名称分别为 `data_batch_1`、`data_batch_2`，以此类推。每个部分都包含以下某个类别的标签和图片：
#
# * 飞机
# * 汽车
# * 鸟类
# * 猫
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船只
# * 卡车
#
# 了解数据集也是对数据进行预测的必经步骤。你可以通过更改 `batch_id` 和 `sample_id` 探索下面的代码单元。`batch_id` 是数据集一个部分的 ID（1 到 5）。`sample_id` 是该部分中图片和标签对（label pair）的 ID。
#
# 问问你自己：“可能的标签有哪些？”、“图片数据的值范围是多少？”、“标签是按顺序排列，还是随机排列的？”。思考类似的问题，有助于你预处理数据，并使预测结果更准确。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## 实现预处理函数
#
# ### 标准化
#
# 在下面的单元中，实现 `normalize` 函数，传入图片数据 `x`，并返回标准化 Numpy 数组。值应该在 0 到 1 的范围内（含 0 和 1）。返回对象应该和 `x` 的形状一样。

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # 方便计算直接可以除以255（图片像素灰度范围在0-255之间）
    # 也可以 (x-128)/128
    return x / 255.0


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot 编码
#
# 和之前的代码单元一样，你将为预处理实现一个函数。这次，你将实现 `one_hot_encode` 函数。输入，也就是 `x`，是一个标签列表。实现该函数，以返回为 one_hot 编码的 Numpy 数组的标签列表。标签的可能值为 0 到 9。每次调用 `one_hot_encode` 时，对于每个值，one_hot 编码函数应该返回相同的编码。确保将编码映射保存到该函数外面。
#
# 提示：不要重复发明轮子。

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    # 可以参考课程实现，使用scikit-learn LabelBinarizer
    # from sklearn import preprocessing
    # 1b = preprocessing.LabelBinarizer()
    # 1b.fit(x)
    # 1b.transform(x)
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### 随机化数据
#
# 之前探索数据时，你已经了解到，样本的顺序是随机的。再随机化一次也不会有什么关系，但是对于这个数据集没有必要。

# %% [markdown]
# ## 预处理所有数据并保存
#
# 运行下方的代码单元，将预处理所有 CIFAR-10 数据，并保存到文件中。下面的代码还使用了 10% 的训练数据，用来验证。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，你可以从这里开始。预处理的数据已保存到本地。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## 构建网络
#
# 对于该神经网络，你需要将每层都构建为一个函数。你看到的大部分代码都位于函数外面。要更全面地测试你的代码，我们需要你将每层放入一个函数中。这样使我们能够提供更好的反馈，并使用我们的统一测试检测简单的错误，然后再提交项目。
#
# >**注意**：如果你觉得每周很难抽出足够的时间学习这门课程，我们为此项目提供了一个小捷径。对于接下来的几个问题，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 程序包中的类来构建每个层级，但是“卷积和最大池化层级”部分的层级除外。TF Layers 和 Keras 及 TFLearn 层级类似，因此很容易学会。
#
# >但是，如果你想充分利用这门课程，请尝试自己解决所有问题，不使用 TF Layers 程序包中的任何类。你依然可以使用其他程序包中的类，这些类和你在 TF Layers 中的类名称是一样的！例如，你可以使用 TF Neural Network 版本的 `conv2d` 类 [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)，而不是 TF Layers 版本的 `conv2d` 类 [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d)。
#
# 我们开始吧！
#
#
# ### 输入
#
# 神经网络需要读取图片数据、one-hot 编码标签和丢弃保留概率（dropout keep probability）。请实现以下函数：
#
# * 实现 `neural_net_image_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `image_shape` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "x" 命名
# * 实现 `neural_net_label_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `n_classes` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "y" 命名
# * 实现 `neural_net_keep_prob_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)，用于丢弃保留概率
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "keep_prob" 命名
#
# 这些名称将在项目结束时，用于加载保存的模型。
#
# 注意：TensorFlow 中的 `None` 表示形状可以是动态大小。

# %%
import tensorflow as tf

# tensorflow 用tf.placeholder()来hold值, 之后在session.run函数得到tensor（feed_dict喂数据)。
# 如feed_dict{x;vaule1, y:value2}

# 一般从正态分布中选择权重tf.truncated_normal()
#
# n_features = 120
# n_labels = 5
# weights = tf.Variable(tf.truncated_normal((n_features, n_labels))) 注意括号
# 一般而言，bia 设置为0，bias = tf.Variable(tf.zeros(n_labels))

# Softmax 函数可以把它的输入，通常被称为 logits 或者 logit scores，处理成 0 到 1 之间，
#并且能够把输出归一化到和为 1。这意味着 softmax 函数与分类的概率分布等价。
#它是一个网络预测多分类问题的最佳输出激活函数。tf.nn.softmax([])

# None 维度在这里是一个 batch size 的占位符。
# 在运行时，TensorFlow 会接收任何大于 0 的 batch size。

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images( 数据集图像大小为(32,32,3))（行，列，3通道）
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32, shape=[None, image_shape[0],
                                                   image_shape[1],image_shape[2]],
                          name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### 卷积和最大池化层
#
# 卷积层级适合处理图片。对于此代码单元，你应该实现函数 `conv2d_maxpool` 以便应用卷积然后进行最大池化：
#
# * 使用 `conv_ksize`、`conv_num_outputs` 和 `x_tensor` 的形状创建权重（weight）和偏置（bias）。
# * 使用权重和 `conv_strides` 对 `x_tensor` 应用卷积。
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
# * 添加偏置
# * 向卷积中添加非线性激活（nonlinear activation）
# * 使用 `pool_ksize` 和 `pool_strides` 应用最大池化
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
#
# **注意**：对于**此层**，**请勿使用** [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers)，但是仍然可以使用 TensorFlow 的 [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) 包。对于所有**其他层**，你依然可以使用快捷方法。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # 颜色通道
    # ksize 和 strides 参数也被构建为四个元素的列表，
    # 每个元素对应 input tensor 的一个维度 ([batch, height, width, channels])，
    # 对 ksize 和 strides 来说，batch 和 channel 通常都设置成 1。
    
    color_channels = x_tensor.shape[3].value
    filter_weights = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],color_channels,conv_num_outputs],
                          mean = 0, stddev = 0.1))
    filter_bias = tf.Variable(tf.zeros(conv_num_outputs))
                          
    #卷积
    conv_layer = tf.nn.conv2d(x_tensor, filter_weights, strides=[1, conv_strides[0],conv_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, filter_bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    #最大池化

    conv_layer = tf.nn.max_pool(conv_layer, ksize=[1, pool_ksize[0], pool_ksize[1],1], 
                          strides=[1, pool_strides[0],pool_strides[1], 1], padding='SAME')
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### 扁平化层
#
# 实现 `flatten` 函数，将 `x_tensor` 的维度从四维张量（4-D tensor）变成二维张量。输出应该是形状（*部分大小（Batch Size）*，*扁平化图片大小（Flattened Image Size）*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### 完全连接的层
#
# 实现 `fully_conn` 函数，以向 `x_tensor` 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    fully_layer = tf.contrib.layers.fully_connected(x_tensor, num_outputs, tf.nn.relu)
    
    
    return fully_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### 输出层
#
# 实现 `output` 函数，向 x_tensor 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。
#
# **注意**：该层级不应应用 Activation、softmax 或交叉熵（cross entropy）。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    size = x_tensor.shape[1].value
    weights = tf.Variable(tf.truncated_normal([size, num_outputs],mean=0, stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    output_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### 创建卷积模型
#
# 实现函数 `conv_net`， 创建卷积神经网络模型。该函数传入一批图片 `x`，并输出对数（logits）。使用你在上方创建的层创建此模型：
#
# * 应用 1、2 或 3 个卷积和最大池化层（Convolution and Max Pool layers）
# * 应用一个扁平层（Flatten Layer）
# * 应用 1、2 或 3 个完全连接层（Fully Connected Layers）
# * 应用一个输出层（Output Layer）
# * 返回输出
# * 使用 `keep_prob` 向模型中的一个或多个层应用 [TensorFlow 的 Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_ksize = [4,4]
    conv_strides = [1,1]
    pool_ksize = [2,2]
    pool_strides = [2,2]
    
    layer_1 = conv2d_maxpool(x, 16, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer_2 = conv2d_maxpool(x, 32, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer_3 = conv2d_maxpool(x, 64, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat_layer = flatten(layer_2)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully_connected = fully_conn(flat_layer, 10)
    fully_connected = tf.nn.dropout(fully_connected, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out_layer = output(fully_connected, 10)
    
    # TODO: return output
    return out_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## 训练神经网络
#
# ### 单次优化
#
# 实现函数 `train_neural_network` 以进行单次优化（single optimization）。该优化应该使用 `optimizer` 优化 `session`，其中 `feed_dict` 具有以下参数：
#
# * `x` 表示图片输入
# * `y` 表示标签
# * `keep_prob` 表示丢弃的保留率
#
# 每个部分都会调用该函数，所以 `tf.global_variables_initializer()` 已经被调用。
#
# 注意：不需要返回任何内容。该函数只是用来优化神经网络。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### 显示数据
#
# 实现函数 `print_stats` 以输出损失和验证准确率。使用全局变量 `valid_features` 和 `valid_labels` 计算验证准确率。使用保留率 `1.0` 计算损失和验证准确率（loss and validation accuracy）。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost,feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    valid_accur = session.run(accuracy,feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    print('Loss: %f , Validation accuracy: %f' %(loss,valid_accur))

# %% [markdown]
# ### 超参数
#
# 调试以下超参数：
# * 设置 `epochs` 表示神经网络停止学习或开始过拟合的迭代次数
# * 设置 `batch_size`，表示机器内存允许的部分最大体积。大部分人设为以下常见内存大小：
#
#  * 64
#  * 128
#  * 256
#  * ...
# * 设置 `keep_probability` 表示使用丢弃时保留节点的概率

# %%
# TODO: Tune Parameters
epochs = 60
batch_size = 512
keep_probability = 1.0

# %% [markdown]
# ### 在单个 CIFAR-10 部分上训练
#
# 我们先用单个部分，而不是用所有的 CIFAR-10 批次训练神经网络。这样可以节省时间，并对模型进行迭代，以提高准确率。最终验证准确率达到 50% 或以上之后，在下一部分对所有数据运行模型。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.261967 , Validation accuracy: 0.131757
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.171408 , Validation accuracy: 0.179054
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.061460 , Validation accuracy: 0.216216
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1.970101 , Validation accuracy: 0.300676
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.902692 , Validation accuracy: 0.358108
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.853915 , Validation accuracy: 0.378378
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.811646 , Validation accuracy: 0.385135
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.771222 , Validation accuracy: 0.385135
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.733379 , Validation accuracy: 0.398649
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.696868 , Validation accuracy: 0.412162
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.664613 , Validation accuracy: 0.429054
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.633681 , Validation accuracy: 0.432432
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.603783 , Validation accuracy: 0.445946
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.572816 , Validation accuracy: 0.462838
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.545810 , Validation accuracy: 0.469595
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.526313 , Validation accuracy: 0.469595
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.506082 , Validation accuracy: 0.466216
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.485141 , Validation accuracy: 0.469595
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.466509 , Validation accuracy: 0.459459
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.449907 , Validation accuracy: 0.456081
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.434776 , Validation accuracy: 0.459459
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.420361 , Validation accuracy: 0.469595
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.405960 , Validation accuracy: 0.472973
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.392743 , Validation accuracy: 0.479730
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.380924 , Validation accuracy: 0.486486
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.369333 , Validation accuracy: 0.493243
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.357915 , Validation accuracy: 0.483108
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.347246 , Validation accuracy: 0.486486
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.337280 , Validation accuracy: 0.506757
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.327691 , Validation accuracy: 0.513514
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.318641 , Validation accuracy: 0.520270
# Epoch 32, CIFAR-10 Batch 1:  Loss: 1.309890 , Validation accuracy: 0.527027
# Epoch 33, CIFAR-10 Batch 1:  Loss: 1.301277 , Validation accuracy: 0.537162
# Epoch 34, CIFAR-10 Batch 1:  Loss: 1.293383 , Validation accuracy: 0.537162
# Epoch 35, CIFAR-10 Batch 1:  Loss: 1.285355 , Validation accuracy: 0.540541
# Epoch 36, CIFAR-10 Batch 1:  Loss: 1.277315 , Validation accuracy: 0.554054
# Epoch 37, CIFAR-10 Batch 1:  Loss: 1.269811 , Validation accuracy: 0.554054
# Epoch 38, CIFAR-10 Batch 1:  Loss: 1.262397 , Validation accuracy: 0.560811
# Epoch 39, CIFAR-10 Batch 1:  Loss: 1.255063 , Validation accuracy: 0.560811
# Epoch 40, CIFAR-10 Batch 1:  Loss: 1.247339 , Validation accuracy: 0.560811
# Epoch 41, CIFAR-10 Batch 1:  Loss: 1.239961 , Validation accuracy: 0.564189
# Epoch 42, CIFAR-10 Batch 1:  Loss: 1.233069 , Validation accuracy: 0.567568
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.226009 , Validation accuracy: 0.574324
# Epoch 44, CIFAR-10 Batch 1:  Loss: 1.219028 , Validation accuracy: 0.577703
# Epoch 45, CIFAR-10 Batch 1:  Loss: 1.212283 , Validation accuracy: 0.581081
# Epoch 46, CIFAR-10 Batch 1:  Loss: 1.205480 , Validation accuracy: 0.587838
# Epoch 47, CIFAR-10 Batch 1:  Loss: 1.198683 , Validation accuracy: 0.587838
# Epoch 48, CIFAR-10 Batch 1:  Loss: 1.192043 , Validation accuracy: 0.591216
# Epoch 49, CIFAR-10 Batch 1:  Loss: 1.185418 , Validation accuracy: 0.594595
# Epoch 50, CIFAR-10 Batch 1:  Loss: 1.179119 , Validation accuracy: 0.597973
# Epoch 51, CIFAR-10 Batch 1:  Loss: 1.172330 , Validation accuracy: 0.601351
# Epoch 52, CIFAR-10 Batch 1:  Loss: 1.165818 , Validation accuracy: 0.604730
# Epoch 53, CIFAR-10 Batch 1:  Loss: 1.159462 , Validation accuracy: 0.608108
# Epoch 54, CIFAR-10 Batch 1:  Loss: 1.152825 , Validation accuracy: 0.608108
# Epoch 55, CIFAR-10 Batch 1:  Loss: 1.146357 , Validation accuracy: 0.608108
# Epoch 56, CIFAR-10 Batch 1:  Loss: 1.139798 , Validation accuracy: 0.614865
# Epoch 57, CIFAR-10 Batch 1:  Loss: 1.133448 , Validation accuracy: 0.625000
# Epoch 58, CIFAR-10 Batch 1:  Loss: 1.127237 , Validation accuracy: 0.628378
# Epoch 59, CIFAR-10 Batch 1:  Loss: 1.121016 , Validation accuracy: 0.635135
# Epoch 60, CIFAR-10 Batch 1:  Loss: 1.114742 , Validation accuracy: 0.638514

# %% [markdown]
# ### 完全训练模型
#
# 现在，单个 CIFAR-10 部分的准确率已经不错了，试试所有五个部分吧。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.259742 , Validation accuracy: 0.158784
# Epoch  1, CIFAR-10 Batch 2:  Loss: 2.209397 , Validation accuracy: 0.192568
# Epoch  1, CIFAR-10 Batch 3:  Loss: 2.065034 , Validation accuracy: 0.246622
# Epoch  1, CIFAR-10 Batch 4:  Loss: 1.956128 , Validation accuracy: 0.334459
# Epoch  1, CIFAR-10 Batch 5:  Loss: 1.876443 , Validation accuracy: 0.293919
# Epoch  2, CIFAR-10 Batch 1:  Loss: 1.877504 , Validation accuracy: 0.327703
# Epoch  2, CIFAR-10 Batch 2:  Loss: 1.744946 , Validation accuracy: 0.381757
# Epoch  2, CIFAR-10 Batch 3:  Loss: 1.638102 , Validation accuracy: 0.429054
# Epoch  2, CIFAR-10 Batch 4:  Loss: 1.617573 , Validation accuracy: 0.381757
# Epoch  2, CIFAR-10 Batch 5:  Loss: 1.686544 , Validation accuracy: 0.415541
# Epoch  3, CIFAR-10 Batch 1:  Loss: 1.721008 , Validation accuracy: 0.425676
# Epoch  3, CIFAR-10 Batch 2:  Loss: 1.598463 , Validation accuracy: 0.472973
# Epoch  3, CIFAR-10 Batch 3:  Loss: 1.515394 , Validation accuracy: 0.472973
# Epoch  3, CIFAR-10 Batch 4:  Loss: 1.526453 , Validation accuracy: 0.418919
# Epoch  3, CIFAR-10 Batch 5:  Loss: 1.586618 , Validation accuracy: 0.445946
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1.654576 , Validation accuracy: 0.425676
# Epoch  4, CIFAR-10 Batch 2:  Loss: 1.539623 , Validation accuracy: 0.466216
# Epoch  4, CIFAR-10 Batch 3:  Loss: 1.422804 , Validation accuracy: 0.506757
# Epoch  4, CIFAR-10 Batch 4:  Loss: 1.456846 , Validation accuracy: 0.459459
# Epoch  4, CIFAR-10 Batch 5:  Loss: 1.507195 , Validation accuracy: 0.472973
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.606346 , Validation accuracy: 0.422297
# Epoch  5, CIFAR-10 Batch 2:  Loss: 1.506406 , Validation accuracy: 0.459459
# Epoch  5, CIFAR-10 Batch 3:  Loss: 1.379667 , Validation accuracy: 0.516892
# Epoch  5, CIFAR-10 Batch 4:  Loss: 1.407265 , Validation accuracy: 0.476351
# Epoch  5, CIFAR-10 Batch 5:  Loss: 1.453661 , Validation accuracy: 0.472973
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.565374 , Validation accuracy: 0.435811
# Epoch  6, CIFAR-10 Batch 2:  Loss: 1.460488 , Validation accuracy: 0.459459
# Epoch  6, CIFAR-10 Batch 3:  Loss: 1.348345 , Validation accuracy: 0.523649
# Epoch  6, CIFAR-10 Batch 4:  Loss: 1.368316 , Validation accuracy: 0.489865
# Epoch  6, CIFAR-10 Batch 5:  Loss: 1.412970 , Validation accuracy: 0.489865
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.530339 , Validation accuracy: 0.449324
# Epoch  7, CIFAR-10 Batch 2:  Loss: 1.411408 , Validation accuracy: 0.493243
# Epoch  7, CIFAR-10 Batch 3:  Loss: 1.321871 , Validation accuracy: 0.530405
# Epoch  7, CIFAR-10 Batch 4:  Loss: 1.333485 , Validation accuracy: 0.516892
# Epoch  7, CIFAR-10 Batch 5:  Loss: 1.376876 , Validation accuracy: 0.500000
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.500968 , Validation accuracy: 0.449324
# Epoch  8, CIFAR-10 Batch 2:  Loss: 1.365509 , Validation accuracy: 0.496622
# Epoch  8, CIFAR-10 Batch 3:  Loss: 1.297461 , Validation accuracy: 0.530405
# Epoch  8, CIFAR-10 Batch 4:  Loss: 1.304598 , Validation accuracy: 0.523649
# Epoch  8, CIFAR-10 Batch 5:  Loss: 1.343824 , Validation accuracy: 0.500000
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.474370 , Validation accuracy: 0.462838
# Epoch  9, CIFAR-10 Batch 2:  Loss: 1.326163 , Validation accuracy: 0.520270
# Epoch  9, CIFAR-10 Batch 3:  Loss: 1.275537 , Validation accuracy: 0.530405
# Epoch  9, CIFAR-10 Batch 4:  Loss: 1.277486 , Validation accuracy: 0.543919
# Epoch  9, CIFAR-10 Batch 5:  Loss: 1.313601 , Validation accuracy: 0.506757
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.450402 , Validation accuracy: 0.472973
# Epoch 10, CIFAR-10 Batch 2:  Loss: 1.292100 , Validation accuracy: 0.537162
# Epoch 10, CIFAR-10 Batch 3:  Loss: 1.252940 , Validation accuracy: 0.547297
# Epoch 10, CIFAR-10 Batch 4:  Loss: 1.249097 , Validation accuracy: 0.557432
# Epoch 10, CIFAR-10 Batch 5:  Loss: 1.287970 , Validation accuracy: 0.520270
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.425104 , Validation accuracy: 0.486486
# Epoch 11, CIFAR-10 Batch 2:  Loss: 1.268213 , Validation accuracy: 0.537162
# Epoch 11, CIFAR-10 Batch 3:  Loss: 1.226635 , Validation accuracy: 0.554054
# Epoch 11, CIFAR-10 Batch 4:  Loss: 1.225016 , Validation accuracy: 0.550676
# Epoch 11, CIFAR-10 Batch 5:  Loss: 1.264234 , Validation accuracy: 0.533784
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.398302 , Validation accuracy: 0.496622
# Epoch 12, CIFAR-10 Batch 2:  Loss: 1.246915 , Validation accuracy: 0.547297
# Epoch 12, CIFAR-10 Batch 3:  Loss: 1.203823 , Validation accuracy: 0.557432
# Epoch 12, CIFAR-10 Batch 4:  Loss: 1.203972 , Validation accuracy: 0.560811
# Epoch 12, CIFAR-10 Batch 5:  Loss: 1.241502 , Validation accuracy: 0.537162
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.374743 , Validation accuracy: 0.510135
# Epoch 13, CIFAR-10 Batch 2:  Loss: 1.224196 , Validation accuracy: 0.557432
# Epoch 13, CIFAR-10 Batch 3:  Loss: 1.184836 , Validation accuracy: 0.557432
# Epoch 13, CIFAR-10 Batch 4:  Loss: 1.184813 , Validation accuracy: 0.574324
# Epoch 13, CIFAR-10 Batch 5:  Loss: 1.221844 , Validation accuracy: 0.537162
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.354860 , Validation accuracy: 0.506757
# Epoch 14, CIFAR-10 Batch 2:  Loss: 1.201891 , Validation accuracy: 0.567568
# Epoch 14, CIFAR-10 Batch 3:  Loss: 1.167989 , Validation accuracy: 0.560811
# Epoch 14, CIFAR-10 Batch 4:  Loss: 1.165993 , Validation accuracy: 0.581081
# Epoch 14, CIFAR-10 Batch 5:  Loss: 1.202303 , Validation accuracy: 0.543919
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.336512 , Validation accuracy: 0.513514
# Epoch 15, CIFAR-10 Batch 2:  Loss: 1.180824 , Validation accuracy: 0.574324
# Epoch 15, CIFAR-10 Batch 3:  Loss: 1.153342 , Validation accuracy: 0.570946
# Epoch 15, CIFAR-10 Batch 4:  Loss: 1.147859 , Validation accuracy: 0.591216
# Epoch 15, CIFAR-10 Batch 5:  Loss: 1.183826 , Validation accuracy: 0.557432
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.318821 , Validation accuracy: 0.516892
# Epoch 16, CIFAR-10 Batch 2:  Loss: 1.162126 , Validation accuracy: 0.587838
# Epoch 16, CIFAR-10 Batch 3:  Loss: 1.138088 , Validation accuracy: 0.587838
# Epoch 16, CIFAR-10 Batch 4:  Loss: 1.132381 , Validation accuracy: 0.591216
# Epoch 16, CIFAR-10 Batch 5:  Loss: 1.165786 , Validation accuracy: 0.570946
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.301893 , Validation accuracy: 0.513514
# Epoch 17, CIFAR-10 Batch 2:  Loss: 1.146279 , Validation accuracy: 0.601351
# Epoch 17, CIFAR-10 Batch 3:  Loss: 1.122764 , Validation accuracy: 0.584459
# Epoch 17, CIFAR-10 Batch 4:  Loss: 1.117253 , Validation accuracy: 0.591216
# Epoch 17, CIFAR-10 Batch 5:  Loss: 1.149004 , Validation accuracy: 0.574324
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.286442 , Validation accuracy: 0.523649
# Epoch 18, CIFAR-10 Batch 2:  Loss: 1.130750 , Validation accuracy: 0.594595
# Epoch 18, CIFAR-10 Batch 3:  Loss: 1.108989 , Validation accuracy: 0.584459
# Epoch 18, CIFAR-10 Batch 4:  Loss: 1.102714 , Validation accuracy: 0.587838
# Epoch 18, CIFAR-10 Batch 5:  Loss: 1.133560 , Validation accuracy: 0.587838
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.271463 , Validation accuracy: 0.510135
# Epoch 19, CIFAR-10 Batch 2:  Loss: 1.115770 , Validation accuracy: 0.601351
# Epoch 19, CIFAR-10 Batch 3:  Loss: 1.095562 , Validation accuracy: 0.594595
# Epoch 19, CIFAR-10 Batch 4:  Loss: 1.089150 , Validation accuracy: 0.601351
# Epoch 19, CIFAR-10 Batch 5:  Loss: 1.119170 , Validation accuracy: 0.594595
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.257224 , Validation accuracy: 0.513514
# Epoch 20, CIFAR-10 Batch 2:  Loss: 1.102240 , Validation accuracy: 0.614865
# Epoch 20, CIFAR-10 Batch 3:  Loss: 1.083218 , Validation accuracy: 0.597973
# Epoch 20, CIFAR-10 Batch 4:  Loss: 1.076117 , Validation accuracy: 0.618243
# Epoch 20, CIFAR-10 Batch 5:  Loss: 1.105512 , Validation accuracy: 0.601351
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.243542 , Validation accuracy: 0.523649
# Epoch 21, CIFAR-10 Batch 2:  Loss: 1.089492 , Validation accuracy: 0.608108
# Epoch 21, CIFAR-10 Batch 3:  Loss: 1.072082 , Validation accuracy: 0.604730
# Epoch 21, CIFAR-10 Batch 4:  Loss: 1.063372 , Validation accuracy: 0.625000
# Epoch 21, CIFAR-10 Batch 5:  Loss: 1.092650 , Validation accuracy: 0.597973
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.230940 , Validation accuracy: 0.530405
# Epoch 22, CIFAR-10 Batch 2:  Loss: 1.078411 , Validation accuracy: 0.618243
# Epoch 22, CIFAR-10 Batch 3:  Loss: 1.062064 , Validation accuracy: 0.608108
# Epoch 22, CIFAR-10 Batch 4:  Loss: 1.051331 , Validation accuracy: 0.625000
# Epoch 22, CIFAR-10 Batch 5:  Loss: 1.080795 , Validation accuracy: 0.601351
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.218714 , Validation accuracy: 0.540541
# Epoch 23, CIFAR-10 Batch 2:  Loss: 1.067885 , Validation accuracy: 0.618243
# Epoch 23, CIFAR-10 Batch 3:  Loss: 1.053014 , Validation accuracy: 0.625000
# Epoch 23, CIFAR-10 Batch 4:  Loss: 1.039733 , Validation accuracy: 0.625000
# Epoch 23, CIFAR-10 Batch 5:  Loss: 1.070213 , Validation accuracy: 0.608108
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.206965 , Validation accuracy: 0.550676
# Epoch 24, CIFAR-10 Batch 2:  Loss: 1.057257 , Validation accuracy: 0.621622
# Epoch 24, CIFAR-10 Batch 3:  Loss: 1.044658 , Validation accuracy: 0.628378
# Epoch 24, CIFAR-10 Batch 4:  Loss: 1.028817 , Validation accuracy: 0.631757
# Epoch 24, CIFAR-10 Batch 5:  Loss: 1.059437 , Validation accuracy: 0.614865
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.195870 , Validation accuracy: 0.554054
# Epoch 25, CIFAR-10 Batch 2:  Loss: 1.046816 , Validation accuracy: 0.628378
# Epoch 25, CIFAR-10 Batch 3:  Loss: 1.036688 , Validation accuracy: 0.631757
# Epoch 25, CIFAR-10 Batch 4:  Loss: 1.018559 , Validation accuracy: 0.621622
# Epoch 25, CIFAR-10 Batch 5:  Loss: 1.049421 , Validation accuracy: 0.618243
# Epoch 26, CIFAR-10 Batch 1:  Loss: 1.185006 , Validation accuracy: 0.570946
# Epoch 26, CIFAR-10 Batch 2:  Loss: 1.036929 , Validation accuracy: 0.628378
# Epoch 26, CIFAR-10 Batch 3:  Loss: 1.029151 , Validation accuracy: 0.628378
# Epoch 26, CIFAR-10 Batch 4:  Loss: 1.009188 , Validation accuracy: 0.631757
# Epoch 26, CIFAR-10 Batch 5:  Loss: 1.039862 , Validation accuracy: 0.621622
# Epoch 27, CIFAR-10 Batch 1:  Loss: 1.173672 , Validation accuracy: 0.574324
# Epoch 27, CIFAR-10 Batch 2:  Loss: 1.027464 , Validation accuracy: 0.628378
# Epoch 27, CIFAR-10 Batch 3:  Loss: 1.022108 , Validation accuracy: 0.631757
# Epoch 27, CIFAR-10 Batch 4:  Loss: 1.000376 , Validation accuracy: 0.631757
# Epoch 27, CIFAR-10 Batch 5:  Loss: 1.031152 , Validation accuracy: 0.625000
# Epoch 28, CIFAR-10 Batch 1:  Loss: 1.163142 , Validation accuracy: 0.570946
# Epoch 28, CIFAR-10 Batch 2:  Loss: 1.019041 , Validation accuracy: 0.638514
# Epoch 28, CIFAR-10 Batch 3:  Loss: 1.014893 , Validation accuracy: 0.641892
# Epoch 28, CIFAR-10 Batch 4:  Loss: 0.992056 , Validation accuracy: 0.641892
# Epoch 28, CIFAR-10 Batch 5:  Loss: 1.022602 , Validation accuracy: 0.625000
# Epoch 29, CIFAR-10 Batch 1:  Loss: 1.153681 , Validation accuracy: 0.574324
# Epoch 29, CIFAR-10 Batch 2:  Loss: 1.010080 , Validation accuracy: 0.635135
# Epoch 29, CIFAR-10 Batch 3:  Loss: 1.008747 , Validation accuracy: 0.641892
# Epoch 29, CIFAR-10 Batch 4:  Loss: 0.983599 , Validation accuracy: 0.638514
# Epoch 29, CIFAR-10 Batch 5:  Loss: 1.014174 , Validation accuracy: 0.625000
# Epoch 30, CIFAR-10 Batch 1:  Loss: 1.144001 , Validation accuracy: 0.570946
# Epoch 30, CIFAR-10 Batch 2:  Loss: 1.001670 , Validation accuracy: 0.638514
# Epoch 30, CIFAR-10 Batch 3:  Loss: 1.002407 , Validation accuracy: 0.641892
# Epoch 30, CIFAR-10 Batch 4:  Loss: 0.976795 , Validation accuracy: 0.638514
# Epoch 30, CIFAR-10 Batch 5:  Loss: 1.006879 , Validation accuracy: 0.625000
# Epoch 31, CIFAR-10 Batch 1:  Loss: 1.134271 , Validation accuracy: 0.574324
# Epoch 31, CIFAR-10 Batch 2:  Loss: 0.994161 , Validation accuracy: 0.638514
# Epoch 31, CIFAR-10 Batch 3:  Loss: 0.996733 , Validation accuracy: 0.645270
# Epoch 31, CIFAR-10 Batch 4:  Loss: 0.969823 , Validation accuracy: 0.641892
# Epoch 31, CIFAR-10 Batch 5:  Loss: 0.999835 , Validation accuracy: 0.621622
# Epoch 32, CIFAR-10 Batch 1:  Loss: 1.125291 , Validation accuracy: 0.570946
# Epoch 32, CIFAR-10 Batch 2:  Loss: 0.987284 , Validation accuracy: 0.638514
# Epoch 32, CIFAR-10 Batch 3:  Loss: 0.992110 , Validation accuracy: 0.638514
# Epoch 32, CIFAR-10 Batch 4:  Loss: 0.964587 , Validation accuracy: 0.668919
# Epoch 32, CIFAR-10 Batch 5:  Loss: 0.993252 , Validation accuracy: 0.621622
# Epoch 33, CIFAR-10 Batch 1:  Loss: 1.116837 , Validation accuracy: 0.574324
# Epoch 33, CIFAR-10 Batch 2:  Loss: 0.981608 , Validation accuracy: 0.638514
# Epoch 33, CIFAR-10 Batch 3:  Loss: 0.988178 , Validation accuracy: 0.638514
# Epoch 33, CIFAR-10 Batch 4:  Loss: 0.960332 , Validation accuracy: 0.665541
# Epoch 33, CIFAR-10 Batch 5:  Loss: 0.986664 , Validation accuracy: 0.625000
# Epoch 34, CIFAR-10 Batch 1:  Loss: 1.108629 , Validation accuracy: 0.581081
# Epoch 34, CIFAR-10 Batch 2:  Loss: 0.976563 , Validation accuracy: 0.645270
# Epoch 34, CIFAR-10 Batch 3:  Loss: 0.983738 , Validation accuracy: 0.641892
# Epoch 34, CIFAR-10 Batch 4:  Loss: 0.955772 , Validation accuracy: 0.662162
# Epoch 34, CIFAR-10 Batch 5:  Loss: 0.980334 , Validation accuracy: 0.625000
# Epoch 35, CIFAR-10 Batch 1:  Loss: 1.100580 , Validation accuracy: 0.584459
# Epoch 35, CIFAR-10 Batch 2:  Loss: 0.970970 , Validation accuracy: 0.652027
# Epoch 35, CIFAR-10 Batch 3:  Loss: 0.980233 , Validation accuracy: 0.638514
# Epoch 35, CIFAR-10 Batch 4:  Loss: 0.950993 , Validation accuracy: 0.652027
# Epoch 35, CIFAR-10 Batch 5:  Loss: 0.974363 , Validation accuracy: 0.625000
# Epoch 36, CIFAR-10 Batch 1:  Loss: 1.093003 , Validation accuracy: 0.581081
# Epoch 36, CIFAR-10 Batch 2:  Loss: 0.966153 , Validation accuracy: 0.662162
# Epoch 36, CIFAR-10 Batch 3:  Loss: 0.976348 , Validation accuracy: 0.645270
# Epoch 36, CIFAR-10 Batch 4:  Loss: 0.946309 , Validation accuracy: 0.648649
# Epoch 36, CIFAR-10 Batch 5:  Loss: 0.968579 , Validation accuracy: 0.635135
# Epoch 37, CIFAR-10 Batch 1:  Loss: 1.085880 , Validation accuracy: 0.597973
# Epoch 37, CIFAR-10 Batch 2:  Loss: 0.960858 , Validation accuracy: 0.668919
# Epoch 37, CIFAR-10 Batch 3:  Loss: 0.972327 , Validation accuracy: 0.662162
# Epoch 37, CIFAR-10 Batch 4:  Loss: 0.941188 , Validation accuracy: 0.645270
# Epoch 37, CIFAR-10 Batch 5:  Loss: 0.962925 , Validation accuracy: 0.635135
# Epoch 38, CIFAR-10 Batch 1:  Loss: 1.079332 , Validation accuracy: 0.601351
# Epoch 38, CIFAR-10 Batch 2:  Loss: 0.955943 , Validation accuracy: 0.679054
# Epoch 38, CIFAR-10 Batch 3:  Loss: 0.968133 , Validation accuracy: 0.655405
# Epoch 38, CIFAR-10 Batch 4:  Loss: 0.935184 , Validation accuracy: 0.648649
# Epoch 38, CIFAR-10 Batch 5:  Loss: 0.957062 , Validation accuracy: 0.638514
# Epoch 39, CIFAR-10 Batch 1:  Loss: 1.073535 , Validation accuracy: 0.608108
# Epoch 39, CIFAR-10 Batch 2:  Loss: 0.951179 , Validation accuracy: 0.682432
# Epoch 39, CIFAR-10 Batch 3:  Loss: 0.963498 , Validation accuracy: 0.658784
# Epoch 39, CIFAR-10 Batch 4:  Loss: 0.929237 , Validation accuracy: 0.655405
# Epoch 39, CIFAR-10 Batch 5:  Loss: 0.950755 , Validation accuracy: 0.628378
# Epoch 40, CIFAR-10 Batch 1:  Loss: 1.067642 , Validation accuracy: 0.614865
# Epoch 40, CIFAR-10 Batch 2:  Loss: 0.946172 , Validation accuracy: 0.682432
# Epoch 40, CIFAR-10 Batch 3:  Loss: 0.958568 , Validation accuracy: 0.662162
# Epoch 40, CIFAR-10 Batch 4:  Loss: 0.923727 , Validation accuracy: 0.658784
# Epoch 40, CIFAR-10 Batch 5:  Loss: 0.945023 , Validation accuracy: 0.628378
# Epoch 41, CIFAR-10 Batch 1:  Loss: 1.061802 , Validation accuracy: 0.621622
# Epoch 41, CIFAR-10 Batch 2:  Loss: 0.941309 , Validation accuracy: 0.682432
# Epoch 41, CIFAR-10 Batch 3:  Loss: 0.954437 , Validation accuracy: 0.665541
# Epoch 41, CIFAR-10 Batch 4:  Loss: 0.918662 , Validation accuracy: 0.658784
# Epoch 41, CIFAR-10 Batch 5:  Loss: 0.939033 , Validation accuracy: 0.641892
# Epoch 42, CIFAR-10 Batch 1:  Loss: 1.055367 , Validation accuracy: 0.625000
# Epoch 42, CIFAR-10 Batch 2:  Loss: 0.935432 , Validation accuracy: 0.685811
# Epoch 42, CIFAR-10 Batch 3:  Loss: 0.949000 , Validation accuracy: 0.665541
# Epoch 42, CIFAR-10 Batch 4:  Loss: 0.913061 , Validation accuracy: 0.658784
# Epoch 42, CIFAR-10 Batch 5:  Loss: 0.933075 , Validation accuracy: 0.641892
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.049064 , Validation accuracy: 0.638514
# Epoch 43, CIFAR-10 Batch 2:  Loss: 0.928985 , Validation accuracy: 0.689189
# Epoch 43, CIFAR-10 Batch 3:  Loss: 0.943571 , Validation accuracy: 0.668919
# Epoch 43, CIFAR-10 Batch 4:  Loss: 0.907940 , Validation accuracy: 0.662162
# Epoch 43, CIFAR-10 Batch 5:  Loss: 0.927030 , Validation accuracy: 0.645270
# Epoch 44, CIFAR-10 Batch 1:  Loss: 1.042478 , Validation accuracy: 0.638514
# Epoch 44, CIFAR-10 Batch 2:  Loss: 0.922936 , Validation accuracy: 0.689189
# Epoch 44, CIFAR-10 Batch 3:  Loss: 0.938505 , Validation accuracy: 0.665541
# Epoch 44, CIFAR-10 Batch 4:  Loss: 0.903174 , Validation accuracy: 0.658784
# Epoch 44, CIFAR-10 Batch 5:  Loss: 0.920850 , Validation accuracy: 0.652027
# Epoch 45, CIFAR-10 Batch 1:  Loss: 1.036476 , Validation accuracy: 0.641892
# Epoch 45, CIFAR-10 Batch 2:  Loss: 0.917270 , Validation accuracy: 0.695946
# Epoch 45, CIFAR-10 Batch 3:  Loss: 0.934390 , Validation accuracy: 0.672297
# Epoch 45, CIFAR-10 Batch 4:  Loss: 0.898237 , Validation accuracy: 0.658784
# Epoch 45, CIFAR-10 Batch 5:  Loss: 0.914806 , Validation accuracy: 0.645270
# Epoch 46, CIFAR-10 Batch 1:  Loss: 1.029318 , Validation accuracy: 0.638514
# Epoch 46, CIFAR-10 Batch 2:  Loss: 0.910908 , Validation accuracy: 0.695946
# Epoch 46, CIFAR-10 Batch 3:  Loss: 0.929612 , Validation accuracy: 0.672297
# Epoch 46, CIFAR-10 Batch 4:  Loss: 0.893705 , Validation accuracy: 0.658784
# Epoch 46, CIFAR-10 Batch 5:  Loss: 0.908972 , Validation accuracy: 0.648649
# Epoch 47, CIFAR-10 Batch 1:  Loss: 1.023091 , Validation accuracy: 0.638514
# Epoch 47, CIFAR-10 Batch 2:  Loss: 0.904450 , Validation accuracy: 0.689189
# Epoch 47, CIFAR-10 Batch 3:  Loss: 0.925359 , Validation accuracy: 0.672297
# Epoch 47, CIFAR-10 Batch 4:  Loss: 0.889302 , Validation accuracy: 0.658784
# Epoch 47, CIFAR-10 Batch 5:  Loss: 0.902757 , Validation accuracy: 0.655405
# Epoch 48, CIFAR-10 Batch 1:  Loss: 1.016491 , Validation accuracy: 0.641892
# Epoch 48, CIFAR-10 Batch 2:  Loss: 0.897974 , Validation accuracy: 0.682432
# Epoch 48, CIFAR-10 Batch 3:  Loss: 0.920280 , Validation accuracy: 0.675676
# Epoch 48, CIFAR-10 Batch 4:  Loss: 0.884487 , Validation accuracy: 0.662162
# Epoch 48, CIFAR-10 Batch 5:  Loss: 0.897077 , Validation accuracy: 0.662162
# Epoch 49, CIFAR-10 Batch 1:  Loss: 1.009998 , Validation accuracy: 0.648649
# Epoch 49, CIFAR-10 Batch 2:  Loss: 0.892317 , Validation accuracy: 0.685811
# Epoch 49, CIFAR-10 Batch 3:  Loss: 0.916105 , Validation accuracy: 0.675676
# Epoch 49, CIFAR-10 Batch 4:  Loss: 0.880267 , Validation accuracy: 0.662162
# Epoch 49, CIFAR-10 Batch 5:  Loss: 0.891295 , Validation accuracy: 0.665541
# Epoch 50, CIFAR-10 Batch 1:  Loss: 1.003497 , Validation accuracy: 0.655405
# Epoch 50, CIFAR-10 Batch 2:  Loss: 0.886614 , Validation accuracy: 0.689189
# Epoch 50, CIFAR-10 Batch 3:  Loss: 0.911574 , Validation accuracy: 0.675676
# Epoch 50, CIFAR-10 Batch 4:  Loss: 0.875409 , Validation accuracy: 0.672297
# Epoch 50, CIFAR-10 Batch 5:  Loss: 0.886051 , Validation accuracy: 0.665541
# Epoch 51, CIFAR-10 Batch 1:  Loss: 0.997114 , Validation accuracy: 0.662162
# Epoch 51, CIFAR-10 Batch 2:  Loss: 0.880984 , Validation accuracy: 0.685811
# Epoch 51, CIFAR-10 Batch 3:  Loss: 0.906686 , Validation accuracy: 0.685811
# Epoch 51, CIFAR-10 Batch 4:  Loss: 0.870549 , Validation accuracy: 0.675676
# Epoch 51, CIFAR-10 Batch 5:  Loss: 0.880747 , Validation accuracy: 0.665541
# Epoch 52, CIFAR-10 Batch 1:  Loss: 0.991265 , Validation accuracy: 0.668919
# Epoch 52, CIFAR-10 Batch 2:  Loss: 0.875390 , Validation accuracy: 0.689189
# Epoch 52, CIFAR-10 Batch 3:  Loss: 0.902550 , Validation accuracy: 0.689189
# Epoch 52, CIFAR-10 Batch 4:  Loss: 0.865667 , Validation accuracy: 0.685811
# Epoch 52, CIFAR-10 Batch 5:  Loss: 0.875848 , Validation accuracy: 0.672297
# Epoch 53, CIFAR-10 Batch 1:  Loss: 0.984971 , Validation accuracy: 0.668919
# Epoch 53, CIFAR-10 Batch 2:  Loss: 0.869172 , Validation accuracy: 0.689189
# Epoch 53, CIFAR-10 Batch 3:  Loss: 0.897981 , Validation accuracy: 0.692568
# Epoch 53, CIFAR-10 Batch 4:  Loss: 0.860832 , Validation accuracy: 0.689189
# Epoch 53, CIFAR-10 Batch 5:  Loss: 0.870425 , Validation accuracy: 0.672297
# Epoch 54, CIFAR-10 Batch 1:  Loss: 0.978727 , Validation accuracy: 0.672297
# Epoch 54, CIFAR-10 Batch 2:  Loss: 0.863336 , Validation accuracy: 0.692568
# Epoch 54, CIFAR-10 Batch 3:  Loss: 0.893273 , Validation accuracy: 0.692568
# Epoch 54, CIFAR-10 Batch 4:  Loss: 0.855928 , Validation accuracy: 0.692568
# Epoch 54, CIFAR-10 Batch 5:  Loss: 0.865167 , Validation accuracy: 0.675676
# Epoch 55, CIFAR-10 Batch 1:  Loss: 0.972872 , Validation accuracy: 0.672297
# Epoch 55, CIFAR-10 Batch 2:  Loss: 0.857729 , Validation accuracy: 0.695946
# Epoch 55, CIFAR-10 Batch 3:  Loss: 0.888891 , Validation accuracy: 0.695946
# Epoch 55, CIFAR-10 Batch 4:  Loss: 0.851316 , Validation accuracy: 0.692568
# Epoch 55, CIFAR-10 Batch 5:  Loss: 0.859761 , Validation accuracy: 0.675676
# Epoch 56, CIFAR-10 Batch 1:  Loss: 0.966641 , Validation accuracy: 0.672297
# Epoch 56, CIFAR-10 Batch 2:  Loss: 0.852376 , Validation accuracy: 0.689189
# Epoch 56, CIFAR-10 Batch 3:  Loss: 0.884516 , Validation accuracy: 0.692568
# Epoch 56, CIFAR-10 Batch 4:  Loss: 0.847331 , Validation accuracy: 0.695946
# Epoch 56, CIFAR-10 Batch 5:  Loss: 0.854495 , Validation accuracy: 0.679054
# Epoch 57, CIFAR-10 Batch 1:  Loss: 0.961041 , Validation accuracy: 0.675676
# Epoch 57, CIFAR-10 Batch 2:  Loss: 0.846823 , Validation accuracy: 0.692568
# Epoch 57, CIFAR-10 Batch 3:  Loss: 0.879237 , Validation accuracy: 0.689189
# Epoch 57, CIFAR-10 Batch 4:  Loss: 0.842623 , Validation accuracy: 0.695946
# Epoch 57, CIFAR-10 Batch 5:  Loss: 0.849314 , Validation accuracy: 0.679054
# Epoch 58, CIFAR-10 Batch 1:  Loss: 0.955029 , Validation accuracy: 0.672297
# Epoch 58, CIFAR-10 Batch 2:  Loss: 0.840859 , Validation accuracy: 0.702703
# Epoch 58, CIFAR-10 Batch 3:  Loss: 0.874972 , Validation accuracy: 0.685811
# Epoch 58, CIFAR-10 Batch 4:  Loss: 0.838726 , Validation accuracy: 0.695946
# Epoch 58, CIFAR-10 Batch 5:  Loss: 0.844085 , Validation accuracy: 0.685811
# Epoch 59, CIFAR-10 Batch 1:  Loss: 0.949680 , Validation accuracy: 0.679054
# Epoch 59, CIFAR-10 Batch 2:  Loss: 0.835250 , Validation accuracy: 0.706081
# Epoch 59, CIFAR-10 Batch 3:  Loss: 0.869941 , Validation accuracy: 0.689189
# Epoch 59, CIFAR-10 Batch 4:  Loss: 0.834526 , Validation accuracy: 0.695946
# Epoch 59, CIFAR-10 Batch 5:  Loss: 0.838934 , Validation accuracy: 0.692568
# Epoch 60, CIFAR-10 Batch 1:  Loss: 0.944005 , Validation accuracy: 0.679054
# Epoch 60, CIFAR-10 Batch 2:  Loss: 0.830330 , Validation accuracy: 0.706081
# Epoch 60, CIFAR-10 Batch 3:  Loss: 0.865370 , Validation accuracy: 0.692568
# Epoch 60, CIFAR-10 Batch 4:  Loss: 0.830409 , Validation accuracy: 0.695946
# Epoch 60, CIFAR-10 Batch 5:  Loss: 0.833898 , Validation accuracy: 0.689189

# %% [markdown]
# # 检查点
#
# 模型已保存到本地。
#
# ## 测试模型
#
# 利用测试数据集测试你的模型。这将是最终的准确率。你的准确率应该高于 50%。如果没达到，请继续调整模型结构和参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5922736674547195

# %% [markdown]
# ## 为何准确率只有50-80%？
#
# 你可能想问，为何准确率不能更高了？首先，对于简单的 CNN 网络来说，50% 已经不低了。纯粹猜测的准确率为10%。但是，你可能注意到有人的准确率[远远超过 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130)。这是因为我们还没有介绍所有的神经网络知识。我们还需要掌握一些其他技巧。
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。将 notebook 文件另存为“dlnd_image_classification.ipynb”，再在目录 "File" -> "Download as" 另存为 HTML 格式。请在提交的项目中包含 “helper.py” 和 “problem_unittests.py” 文件。
